# %%
import pandas as pd
import time
import csv
import re
df=pd.read_csv('zf_sPerMeNG_intestine MS2 summary from 48127 at 20230611-182546 20230611-194107 predictedcomp.csv', header =None, sep ='\t')
df.reset_index(drop=True)
df.head(10)
# Out:
#     0         1           2                  3                  4   \
# 0  NaN  entry no  MS1scan no  MS1Isolation mass     MS1monoIsomass
# 1  0.0         1         164  532.8548583984375  532.8548583984375
# 2  1.0         2         180  617.8327026367188  617.8327026367188
# 3  2.0         3         183  860.7320556640625  860.7320556640625
# 4  3.0         4         188  532.8550415039062  532.8550415039062
# 5  4.0         5         191  775.7548217773438  775.7548217773438
# 6  5.0         6         195  866.7496337890625  866.7496337890625
# 7  6.0         7         198  690.7764892578125  690.7764892578125
# 8  7.0         8         198  872.7678833007812  872.7678833007812
# 9  8.0         9         209   945.711181640625   945.711181640625
#
#             5                   6                   7              8   \
# 0  chargeState             in [H+]       intensityN\/A  StructureN\/A
# 1            3  1596.5488951953123  ext from peak list   structure na
# ...

# %%
df.drop(columns=df.columns[0], axis=1, inplace=True)
df.head(5)
# Out:
#            2                  3                  4            5   \
# 0  MS1scan no  MS1Isolation mass     MS1monoIsomass  chargeState
# 1         164  532.8548583984375  532.8548583984375            3
# 2         180  617.8327026367188  617.8327026367188            2
# 3         183  860.7320556640625  860.7320556640625            2
# 4         188  532.8550415039062  532.8550415039062            3
#
#                    6                   7              8            9   \
# 0             in [H+]       intensityN\/A  StructureN\/A  MS2 Scan no
# 1  1596.5488951953123  ext from peak list   structure na          166
# 2  1234.6575652734375  ext from peak list   structure na          182
# 3   1720.456271328125  ext from peak list   structure na          185
# 4  1596.5494445117188  ext from peak list   structure na          190
#
#                                                   10                     11
# 0                                           peaklist  Predicted composition
# ...

# %%
import pandas as pd
import time
import csv
import re
df=pd.read_csv('zf_sPerMeNG_intestine MS2 summary from 48127 at 20230611-182546 20230611-194107 predictedcomp.csv', header =None)
df.head(10)

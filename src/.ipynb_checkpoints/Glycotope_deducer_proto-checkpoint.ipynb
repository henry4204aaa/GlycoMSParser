# %%
#this cell read files and find out it's composition
import pandas as pd
import time
import csv
import re
res=pd.read_csv('zfNGintenstine_20230612_cloud.csv')
res.head(3)
# Out:
#    entry no  MS1scan no  MS1Isolation mass  MS1monoIsomass  chargeState  \
# 0      7646       11981         820.431763      820.431763            2
# 1      8952       14126         820.431946      820.431946            2
# 2      7747       12144         820.432129      820.432129            2
#
#   man_check      in [H+] Structure  MS2 Scan no  \
# 0        ok  1639.855685      H3N4        12012
# 1        ok  1639.856052      H3N4        14168
# 2        ok  1639.856418      H3N4        12180
#
#                                             peaklist  \
# 0  MS2peaklist(dMass=(94.06507110595703, 95.04923...
# 1  MS2peaklist(dMass=(94.06503295898438, 95.04909...
# 2  MS2peaklist(dMass=(90.99137115478516, 94.06515...
#
#                         predictedcomp  \
# 0  [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 1  [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 2  [(1639.854, '(0, 3, 4, 0, 0, 0)')]
#
#                                          hitpeaklist  \
# 0  [246.133, 260.149, 344.17, 374.182, 406.203, 4...
# 1  [246.133, 260.149, 344.17, 374.18, 432.222, 45...
# 2  [246.133, 260.149, 406.205, 432.222, 450.233, ...
#
#                                selectedpeakintensity  \
# 0  [247086.656, 1949057.75, 11567.055, 3674.197, ...
# 1  [19875.078, 1550164.375, 7586.966, 8253.765, 1...
# 2  [1047479.938, 6574079.5, 42170.711, 1398368.12...
#
#                          normalizedselectedintensity
# 0  [12.67723626967954, 100.0, 0.5934690749927753,...
# 1  [1.2821271292600827, 100.0, 0.4894297741812057...
# 2  [15.933484497715611, 100.0, 0.641469440702687,...

# %%
#if the file doesn't include the theoretical value, calculate

#res["peaklist"][1]

def structuretodictparser(dataframe):
    #should be selectable in future
    newdf = dataframe
    exportdf = []
    #handling the data in a df
    newdf.insert(8, 'Structure dict',"")
    for i in range(len(newdf)):
        parser = newdf.iloc[i]['Structure']
        strucdict = {}
        strucdictcom = pd.DataFrame()
        tmpseries = ()
        #start from F
        fuc = re.search('F\d+', parser)
        hexose = re.search('H\d+', parser)
        hexnac = re.search('N\d+', parser)
        neu5ac = re.search('S\d+', parser)
        neu5gc = re.search('G\d+', parser)
        #ambigious strings, get nothing if not present
        Naadduct = re.search('Na', parser)   # if not Naadduct: do nothing ; else add an adduct
        sus = re.search('\?', parser)
        #not included in the first test data
        kdn = re.search('Kdn\d+', parser)
        NH3adduct = re.search('NH3', parser) #may be removed if we calculate this in other function
        Kadduct = re.search('K', parser)
        #conbine the  info into single list in each loop
        if not fuc:
            strucdict.update({'F': 0})
        else:
            strucdict.update({'F': (fuc.group()[1:])})
        if not hexose:
            strucdict.update({'H': 0})
        else:
            strucdict.update({'H': (hexose.group()[1:])})
        if not hexnac:
            strucdict.update({'N': 0})
        else:
            strucdict.update({'N': (hexnac.group()[1:])})
        if not neu5ac:
            strucdict.update({'S': 0})
        else:
            strucdict.update({'S': (neu5ac.group()[1:])})
        if not neu5gc:
            strucdict.update({'G': 0})
        else:
            strucdict.update({'G': (neu5gc.group()[1:])})
        if not kdn:
            strucdict.update({'KDN': 0})
        else:
            strucdict.update({'KDN': (kdn.group()[1:])})
        # I won't add them as default since they are exceptions.
        if not Naadduct:
            pass
            #strucdict.update({'Na': 0) if the loop on the list throws an error, try this
        else:
            strucdict.update({'Na': 1})
        if not sus:
            pass
            #strucdict.update({'Questionable': 0) if the loop on the list throws an error, try this
        else:
            strucdict.update({'Questionable': 1})
        tmpseries = newdf.iloc[i][1:]
        tmpseries['Structure dict'] = strucdict
        exportdf.append(tmpseries)
    exportdf = pd.DataFrame(exportdf)
    exportdf = exportdf.reset_index(drop=True)
    print(exportdf)
    exportdf.to_csv("revised_zfNGintenstine_20230612_cloud.csv", sep='\t')
    #replace the iloc[i]['Structure']  <- SettingWithCopyWarning and the df is not modified.

structuretodictparser(res)
# Out:
#      MS1scan no  MS1Isolation mass  MS1monoIsomass  chargeState   man_check  \
# 0         11981         820.431763      820.431763            2          ok
# 1         14126         820.431946      820.431946            2          ok
# 2         12144         820.432129      820.432129            2          ok
# 3         12296         820.432312      820.432312            2          ok
# 4         14284         820.432617      820.432617            2          ok
# ..          ...                ...             ...          ...         ...
# 246       31909        1186.604248     1186.268188            3  wrong anno
# 247       32264        1186.604492     1186.265137            3  wrong anno
# 248       31732        1186.604858     1186.268799            3  wrong anno
# 249       30253        1186.618896     1186.273926            3          IF
# 250       22265        1794.408447     1793.909302            2   ok (10e5)
#
#          in [H+]   Structure  \
# 0    1639.855685        H3N4
# 1    1639.856052        H3N4
# 2    1639.856418        H3N4
# 3    1639.856784        H3N4
# 4    1639.857394        H3N4
# ..           ...         ...
# 246  3557.797064  F2H7N4S1G1
# 247  3557.797797  F2H7N4S1G1
# 248  3557.798895  F2H7N4S1G1
# 249  3557.841009  F2H7N4S1G1
# 250  3587.809055    F2H7N4G2
#
#                                         Structure dict  MS2 Scan no  \
# 0    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        12012
# 1    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        14168
# 2    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        12180
# 3    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        12333
# 4    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        14318
# ..                                                 ...          ...
# 246  {'F': '2', 'H': '7', 'N': '4', 'S': '1', 'G': ...        31945
# 247  {'F': '2', 'H': '7', 'N': '4', 'S': '1', 'G': ...        32315
# 248  {'F': '2', 'H': '7', 'N': '4', 'S': '1', 'G': ...        31771
# 249  {'F': '2', 'H': '7', 'N': '4', 'S': '1', 'G': ...        30320
# 250  {'F': '2', 'H': '7', 'N': '4', 'S': 0, 'G': '2...        22307
#
#                                               peaklist  \
# 0    MS2peaklist(dMass=(94.06507110595703, 95.04923...
# 1    MS2peaklist(dMass=(94.06503295898438, 95.04909...
# 2    MS2peaklist(dMass=(90.99137115478516, 94.06515...
# 3    MS2peaklist(dMass=(92.29387664794922, 94.06515...
# 4    MS2peaklist(dMass=(94.06523895263672, 95.04909...
# ..                                                 ...
# 246  MS2peaklist(dMass=(91.73661804199219, 95.04911...
# 247  MS2peaklist(dMass=(95.04898834228516, 97.06465...
# 248  MS2peaklist(dMass=(95.04917907714844, 97.06477...
# 249  MS2peaklist(dMass=(95.04899597167969, 97.06468...
# 250  MS2peaklist(dMass=(92.36995697021484, 96.29338...
#
#                                          predictedcomp  \
# 0                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 1                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 2                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 3                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 4                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# ..                                                 ...
# 246  [(3554.797, '(2, 4, 5, 0, 2, 1)'), (3554.797, ...
# 247  [(3554.797, '(2, 4, 5, 0, 2, 1)'), (3554.797, ...
# 248  [(3554.797, '(2, 4, 5, 0, 2, 1)'), (3554.797, ...
# 249  [(3554.797, '(2, 4, 5, 0, 2, 1)'), (3554.797, ...
# 250  [(3586.799, '(1, 4, 3, 1, 2, 2)'), (3586.799, ...
#
#                                            hitpeaklist  \
# 0    [246.133, 260.149, 344.17, 374.182, 406.203, 4...
# 1    [246.133, 260.149, 344.17, 374.18, 432.222, 45...
# 2    [246.133, 260.149, 406.205, 432.222, 450.233, ...
# 3    [246.133, 260.149, 344.17, 374.18, 406.207, 43...
# 4    [246.134, 260.149, 344.171, 374.182, 432.222, ...
# ..                                                 ...
# 246  [246.133, 260.149, 303.143, 374.181, 376.196, ...
# 247  [246.133, 260.149, 303.143, 374.18, 376.196, 4...
# 248  [246.133, 260.149, 303.143, 374.181, 376.196, ...
# 249  [246.133, 260.149, 303.143, 344.17, 374.18, 37...
# 250  [246.133, 260.149, 344.17, 374.18, 376.195, 40...
#
#                                  selectedpeakintensity  \
# 0    [247086.656, 1949057.75, 11567.055, 3674.197, ...
# 1    [19875.078, 1550164.375, 7586.966, 8253.765, 1...
# 2    [1047479.938, 6574079.5, 42170.711, 1398368.12...
# 3    [183196.031, 1385752.875, 11007.416, 5626.116,...
# 4    [23590.367, 2270437.5, 7480.896, 4565.527, 217...
# ..                                                 ...
# 246  [63275.645, 118640.453, 186261.766, 13771.501,...
# 247  [34777.215, 55538.379, 68762.586, 10407.757, 6...
# 248  [133599.141, 180104.188, 309859.0, 12980.355, ...
# 249  [31415.547, 61683.504, 42143.664, 143781.188, ...
# 250  [5352.57, 16750.465, 23606.576, 302651.406, 73...
#
#                            normalizedselectedintensity
# 0    [12.67723626967954, 100.0, 0.5934690749927753,...
# 1    [1.2821271292600827, 100.0, 0.4894297741812057...
# 2    [15.933484497715611, 100.0, 0.641469440702687,...
# 3    [6.443324806529002, 48.73935219265959, 0.38715...
# 4    [1.039022963635863, 100.0, 0.32949138657197125...
# ..                                                 ...
# 246  [23.4601685565248, 43.987303882915114, 69.0586...
# 247  [34.633076292440016, 55.3081929379753, 68.4775...
# 248  [43.11610797169035, 58.124562462281226, 100.0,...
# 249  [21.849553086179814, 42.900955860790354, 29.31...
# 250  [1.7685594363305217, 5.534573660629219, 7.7999...
#
# [251 rows x 14 columns]

# %%
res2 = pd.read_csv("revised_zfNGintenstine_20230612_cloud.csv", sep ="\t")
res2.reset_index(drop=True)
res2.drop(columns=res2.columns[0], axis=1, inplace=True)
res2.head(5)
# Out:
#    MS1scan no  MS1Isolation mass  MS1monoIsomass  chargeState man_check  \
# 0       11981         820.431763      820.431763            2        ok
# 1       14126         820.431946      820.431946            2        ok
# 2       12144         820.432129      820.432129            2        ok
# 3       12296         820.432312      820.432312            2        ok
# 4       14284         820.432617      820.432617            2        ok
#
#        in [H+] Structure                                     Structure dict  \
# 0  1639.855685      H3N4  {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...
# 1  1639.856052      H3N4  {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...
# 2  1639.856418      H3N4  {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...
# 3  1639.856784      H3N4  {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...
# 4  1639.857394      H3N4  {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...
#
#    MS2 Scan no                                           peaklist  \
# 0        12012  MS2peaklist(dMass=(94.06507110595703, 95.04923...
# 1        14168  MS2peaklist(dMass=(94.06503295898438, 95.04909...
# 2        12180  MS2peaklist(dMass=(90.99137115478516, 94.06515...
# 3        12333  MS2peaklist(dMass=(92.29387664794922, 94.06515...
# 4        14318  MS2peaklist(dMass=(94.06523895263672, 95.04909...
#
#                         predictedcomp  \
# 0  [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 1  [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 2  [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 3  [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 4  [(1639.854, '(0, 3, 4, 0, 0, 0)')]
#
#                                          hitpeaklist  \
# 0  [246.133, 260.149, 344.17, 374.182, 406.203, 4...
# 1  [246.133, 260.149, 344.17, 374.18, 432.222, 45...
# 2  [246.133, 260.149, 406.205, 432.222, 450.233, ...
# 3  [246.133, 260.149, 344.17, 374.18, 406.207, 43...
# 4  [246.134, 260.149, 344.171, 374.182, 432.222, ...
#
#                                selectedpeakintensity  \
# 0  [247086.656, 1949057.75, 11567.055, 3674.197, ...
# 1  [19875.078, 1550164.375, 7586.966, 8253.765, 1...
# 2  [1047479.938, 6574079.5, 42170.711, 1398368.12...
# 3  [183196.031, 1385752.875, 11007.416, 5626.116,...
# 4  [23590.367, 2270437.5, 7480.896, 4565.527, 217...
#
#                          normalizedselectedintensity
# 0  [12.67723626967954, 100.0, 0.5934690749927753,...
# 1  [1.2821271292600827, 100.0, 0.4894297741812057...
# 2  [15.933484497715611, 100.0, 0.641469440702687,...
# 3  [6.443324806529002, 48.73935219265959, 0.38715...
# 4  [1.039022963635863, 100.0, 0.32949138657197125...

# %%
from collections import namedtuple
import numpy as np
import ast
from decimal import *

def deftheoreticalms1(dataframe):
    #should be an element class holding these values
    df = dataframe#pd.read_csv("revised_zfNGbrain_20221129_1_updatedlist_parsed.csv", sep='\t', index_col=[0])
    #askopenfile?
    theomasslist = []
    newdf = pd.DataFrame()
    #print(df.dtypes)
    getcontext().prec = 8
    H = Decimal(1.007825) 
    C = Decimal(12.000)
    O = Decimal(15.9994)
    #N = 14
    Nadif = Decimal(22.989769) - Decimal(1.007825)   #replace H with Na
    mperMedHex = Decimal(174.08921)
    mperMeHex = Decimal(204.09977)
    mperMeHexNAc = Decimal(245.12632)
    mperMeNeu5Ac = Decimal(361.17367)
    mperMeNeu5Gc = Decimal(391.18423)
    mperMeKDN = Decimal(335.1700)
    mperMefreeend = Decimal(46.04186)  #CH3COH3
    mperMeterminal = Decimal(15.023475) #CH3, in positive mode (H+)
    #read the df
    #for testing: obsmass = {'F': 1, 'H':3, 'N': 2, 'S': 0, 'G': 0 }
    #get the structure dict
    for i in range(len(df)):
        tmp = df.iloc[i]['Structure dict']
        obsmass = ast.literal_eval(tmp)
        theomass = 0
        #calculate it
        #print(obsmass, obsmass['F'], type(obsmass['F']))
        Fuc = Decimal(obsmass['F'])
        Hex = Decimal(obsmass['H'])
        HexNAc = Decimal(obsmass['N'])
        Ac = Decimal(obsmass['S'])
        Gc = Decimal(obsmass['G'])
        KDN = Decimal(obsmass['KDN'])
        keys = list(obsmass)
        #print('keys', keys[-1])
        if (keys[-1] == 'Na') or (keys[-2] == 'Na'):
            #print('find Na')
            sodium = 1
        else:
            sodium = 0
        if(keys[-1] == 'Questionable'):
            print('it has a mass difference from theoretical value')
        theomass = str((Fuc * mperMedHex) + (Hex * mperMeHex) + (HexNAc * mperMeHexNAc) + (Ac * mperMeNeu5Ac) + (Gc * mperMeNeu5Gc) + (KDN * mperMeKDN)+ mperMefreeend + H + (Nadif * sodium))
        theomasslist.append(theomass)
    print(theomasslist)
    df.insert(5, 'Theoretical mass' , theomasslist, allow_duplicates = True)
    print(df)
    df.to_csv('Annotated_revised_zfNGintenstine_20230612_cloud.csv', sep='\t', index= False)
    print('finish writing csv')
    #add a new column and insert

# %%
deftheoreticalms1(res2)
# Out:
# ['1639.8543', '1639.8543', '1639.8543', '1639.8543', '1639.8543', '1639.8543', '1639.8543', '1639.8543', '1639.8543', '1639.8543', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1813.9435', '1843.9541', '1884.9806', '1884.9806', '1884.9806', '1884.9806', '1884.9806', '1884.9806', '1884.9806', '1884.9806', '2018.0433', '2048.0539', '2048.0539', '2048.0539', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '2059.0698', '1568.8172', '1568.8172', '1568.8172', '1568.8172', '2222.1431', '2222.1431', '2222.1431', '2222.1431', '2222.1431', '2222.1431', '2222.1431', '2263.1696', '2263.1696', '2263.1696', '2263.1696', '2263.1696', '2263.1696', '2263.1696', '2263.1696', '2263.1696', '2263.1696', '1755.9017', '1755.9017', '2467.2694', '2467.2694', '2467.2694', '2495.2642', '2495.2642', '2495.2642', '2263.1696', '2583.3168', '2263.1696', '2263.1696', '2263.1696', '2583.3168', '2583.3168', '2583.3168', '2583.3168', '2583.3168', '2583.3168', '2583.3168', '2263.1696', '2583.3168', '2624.3433', '2624.3433', '2624.3433', '2624.3433', '2641.3586', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2787.4165', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2961.5057', '2961.5057', '2641.3586', '2641.3586', '2641.3586', '2641.3586', '2641.3586', '2641.3586', '2641.3586', '2641.3586', '2961.5057', '2641.3586', '2641.3586', '2961.5057', '2641.3586', '2961.5057', '2961.5057', '2961.5057', '2961.5057', '2991.5163', '2991.5163', '2991.5163', '2991.5163', '2991.5163', '2991.5163', '2991.5163', '2991.5163', '3049.5581', '3049.5581', '3049.5581', '3049.5581', '2787.4165', '2787.4165', '2467.2694', '2467.2694', '2467.2694', '2787.4165', '2467.2694', '2467.2694', '2467.2694', '2787.4165', '2467.2694', '2787.4165', '2828.4431', '3148.5901', '3148.5901', '3148.5901', '3148.5901', '3148.5901', '3148.5901', '3148.5901', '3148.5901', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2828.4431', '2845.4583', '2845.4583', '3165.6055', '3165.6055', '3165.6055', '3165.6055', '3165.6055', '3165.6055', '3165.6055', '3165.6055', '3165.6055', '3165.6055', '3206.6320', '2886.4849', '3206.6320', '3206.6320', '3206.6320', '3206.6320', '3206.6320', '3206.6320', '3206.6320', '3206.6320', '3206.6320', '3206.6320', '3206.6320', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3526.7791', '3543.7945', '3543.7945', '3543.7945', '3556.7897', '3556.7897', '3556.7897', '3556.7897', '3556.7897', '3556.7897', '3556.7897', '3586.8003']
#      MS1scan no  MS1Isolation mass  MS1monoIsomass  chargeState   man_check  \
# 0         11981         820.431763      820.431763            2          ok
# 1         14126         820.431946      820.431946            2          ok
# 2         12144         820.432129      820.432129            2          ok
# 3         12296         820.432312      820.432312            2          ok
# 4         14284         820.432617      820.432617            2          ok
# ..          ...                ...             ...          ...         ...
# 246       31909        1186.604248     1186.268188            3  wrong anno
# 247       32264        1186.604492     1186.265137            3  wrong anno
# 248       31732        1186.604858     1186.268799            3  wrong anno
# 249       30253        1186.618896     1186.273926            3          IF
# 250       22265        1794.408447     1793.909302            2   ok (10e5)
#
#     Theoretical mass      in [H+]   Structure  \
# 0          1639.8543  1639.855685        H3N4
# 1          1639.8543  1639.856052        H3N4
# 2          1639.8543  1639.856418        H3N4
# 3          1639.8543  1639.856784        H3N4
# 4          1639.8543  1639.857394        H3N4
# ..               ...          ...         ...
# 246        3556.7897  3557.797064  F2H7N4S1G1
# 247        3556.7897  3557.797797  F2H7N4S1G1
# 248        3556.7897  3557.798895  F2H7N4S1G1
# 249        3556.7897  3557.841009  F2H7N4S1G1
# 250        3586.8003  3587.809055    F2H7N4G2
#
#                                         Structure dict  MS2 Scan no  \
# 0    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        12012
# 1    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        14168
# 2    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        12180
# 3    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        12333
# 4    {'F': 0, 'H': '3', 'N': '4', 'S': 0, 'G': 0, '...        14318
# ..                                                 ...          ...
# 246  {'F': '2', 'H': '7', 'N': '4', 'S': '1', 'G': ...        31945
# 247  {'F': '2', 'H': '7', 'N': '4', 'S': '1', 'G': ...        32315
# 248  {'F': '2', 'H': '7', 'N': '4', 'S': '1', 'G': ...        31771
# 249  {'F': '2', 'H': '7', 'N': '4', 'S': '1', 'G': ...        30320
# 250  {'F': '2', 'H': '7', 'N': '4', 'S': 0, 'G': '2...        22307
#
#                                               peaklist  \
# 0    MS2peaklist(dMass=(94.06507110595703, 95.04923...
# 1    MS2peaklist(dMass=(94.06503295898438, 95.04909...
# 2    MS2peaklist(dMass=(90.99137115478516, 94.06515...
# 3    MS2peaklist(dMass=(92.29387664794922, 94.06515...
# 4    MS2peaklist(dMass=(94.06523895263672, 95.04909...
# ..                                                 ...
# 246  MS2peaklist(dMass=(91.73661804199219, 95.04911...
# 247  MS2peaklist(dMass=(95.04898834228516, 97.06465...
# 248  MS2peaklist(dMass=(95.04917907714844, 97.06477...
# 249  MS2peaklist(dMass=(95.04899597167969, 97.06468...
# 250  MS2peaklist(dMass=(92.36995697021484, 96.29338...
#
#                                          predictedcomp  \
# 0                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 1                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 2                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 3                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# 4                   [(1639.854, '(0, 3, 4, 0, 0, 0)')]
# ..                                                 ...
# 246  [(3554.797, '(2, 4, 5, 0, 2, 1)'), (3554.797, ...
# 247  [(3554.797, '(2, 4, 5, 0, 2, 1)'), (3554.797, ...
# 248  [(3554.797, '(2, 4, 5, 0, 2, 1)'), (3554.797, ...
# 249  [(3554.797, '(2, 4, 5, 0, 2, 1)'), (3554.797, ...
# 250  [(3586.799, '(1, 4, 3, 1, 2, 2)'), (3586.799, ...
#
#                                            hitpeaklist  \
# 0    [246.133, 260.149, 344.17, 374.182, 406.203, 4...
# 1    [246.133, 260.149, 344.17, 374.18, 432.222, 45...
# 2    [246.133, 260.149, 406.205, 432.222, 450.233, ...
# 3    [246.133, 260.149, 344.17, 374.18, 406.207, 43...
# 4    [246.134, 260.149, 344.171, 374.182, 432.222, ...
# ..                                                 ...
# 246  [246.133, 260.149, 303.143, 374.181, 376.196, ...
# 247  [246.133, 260.149, 303.143, 374.18, 376.196, 4...
# 248  [246.133, 260.149, 303.143, 374.181, 376.196, ...
# 249  [246.133, 260.149, 303.143, 344.17, 374.18, 37...
# 250  [246.133, 260.149, 344.17, 374.18, 376.195, 40...
#
#                                  selectedpeakintensity  \
# 0    [247086.656, 1949057.75, 11567.055, 3674.197, ...
# 1    [19875.078, 1550164.375, 7586.966, 8253.765, 1...
# 2    [1047479.938, 6574079.5, 42170.711, 1398368.12...
# 3    [183196.031, 1385752.875, 11007.416, 5626.116,...
# 4    [23590.367, 2270437.5, 7480.896, 4565.527, 217...
# ..                                                 ...
# 246  [63275.645, 118640.453, 186261.766, 13771.501,...
# 247  [34777.215, 55538.379, 68762.586, 10407.757, 6...
# 248  [133599.141, 180104.188, 309859.0, 12980.355, ...
# 249  [31415.547, 61683.504, 42143.664, 143781.188, ...
# 250  [5352.57, 16750.465, 23606.576, 302651.406, 73...
#
#                            normalizedselectedintensity
# 0    [12.67723626967954, 100.0, 0.5934690749927753,...
# 1    [1.2821271292600827, 100.0, 0.4894297741812057...
# 2    [15.933484497715611, 100.0, 0.641469440702687,...
# 3    [6.443324806529002, 48.73935219265959, 0.38715...
# 4    [1.039022963635863, 100.0, 0.32949138657197125...
# ..                                                 ...
# 246  [23.4601685565248, 43.987303882915114, 69.0586...
# 247  [34.633076292440016, 55.3081929379753, 68.4775...
# 248  [43.11610797169035, 58.124562462281226, 100.0,...
# 249  [21.849553086179814, 42.900955860790354, 29.31...
# 250  [1.7685594363305217, 5.534573660629219, 7.7999...
#
# [251 rows x 15 columns]
# finish writing csv

# %%
try:
    theoglycotopedict = pd.read_csv("glycotope_deducer.csv")
except:
    theoglycotopedict = {}

# %%
#hand writing rules of glycotopes
glycotopeheader = ["Name of glycotope feature", "used units", "enzyme list and presence 0,1 or ?", "ion list"]
NG_core= ["NG core", {"H":3, "N":2}, {"MGAT1":1 ,"MGAT2":1, "MAN2A1":1 ,"MAN2A2":1, "unknown enzyme": '?'}, [1234.56, 888.88]]
Bisecting_NG_core= ["Bisecting NG core", {"H":3, "N":3}, {"MGAT3": 1}, [1234.56, 888.88]]
Triante_NG_core= ["Tri-antennary N-glycan core", {"H":6, "N":5}, {"MGAT4":1 ,"MGAT5":1}, [1234.56, 888.88]]
NG_elongationGal = ["First and elongation of Galactose at NG ", {"H":1}, {"B4GALT1":1, "B4TALT2~7": 1}, [1234.56, 888.88]] #re?
glycoenzymelist = [glycotopeheader,NG_core,Bisecting_NG_core,NG_elongationGal]
tmp = []
for glycoepitopes in glycoenzymelist:
    tmp.append(glycoepitopes)
print(f"tmp is+ {tmp}")
c = pd.DataFrame(tmp)
c.columns = c.iloc[0]
c = c[1:]
#set first row as index column, copied from https://www.statology.org/pandas-set-first-row-as-header/
c
# Out:
# tmp is+ [['Name of glycotope feature', 'used units', 'enzyme list and presence 0,1 or ?', 'ion list'], ['NG core', {'H': 3, 'N': 2}, {'MGAT1': 1, 'MGAT2': 1, 'MAN2A1': 1, 'MAN2A2': 1, 'unknown enzyme': '?'}, [1234.56, 888.88]], ['Bisecting NG core', {'H': 3, 'N': 3}, {'MGAT3': 1}, [1234.56, 888.88]], ['First and elongation of Galactose at NG ', {'H': 1}, {'B4GALT1': 1, 'B4TALT2~7': 1}, [1234.56, 888.88]]]
# 0                 Name of glycotope feature        used units  \
# 1                                   NG core  {'H': 3, 'N': 2}
# 2                         Bisecting NG core  {'H': 3, 'N': 3}
# 3  First and elongation of Galactose at NG           {'H': 1}
#
# 0                  enzyme list and presence 0,1 or ?           ion list
# 1  {'MGAT1': 1, 'MGAT2': 1, 'MAN2A1': 1, 'MAN2A2'...  [1234.56, 888.88]
# 2                                       {'MGAT3': 1}  [1234.56, 888.88]
# 3                     {'B4GALT1': 1, 'B4TALT2~7': 1}  [1234.56, 888.88]

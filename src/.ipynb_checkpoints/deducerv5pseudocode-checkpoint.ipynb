# %%
F, H, N, S = 1, 7, 6, 4
arms = 4
def avg(u, arms):
    a = u/arms
    return 

for a in range(arms):
    print(arms)
    aF = avg(F, arms)
    aH = avg(H, arms)
    aN = avg(N, arms)
    aS = avg(S, arms)
    print(F, H, N, S)
    arms -=1
# Out:
# 4
# 1 7 6 4
# 3
# 1 7 6 4
# 2
# 1 7 6 4
# 1
# 1 7 6 4
